# %%
import sys        
sys.path.append('/Users/lanabozanic/MATHUSLA') # Change this to the dir where mathusladataprocessing.py is.     

from mathusladataprocessing import *

# %% [markdown]
# Bias voltage used -0.88V

# %%
for f in sorted(glob.glob(os.path.join("1.2mm delays lir", "*.csv"))):
    print(f)
    tds = Timing('t@max', channels=['1', '4'], data = f).td_TAM()
# Out:
# 1.2mm delays lir/0 LIR_delay_327mm_1-2 0.csv
# - Mean: 13.356 ns \\
# - Standard Deviation: 9.583 ns \\
# - Median: 14.000 ns \\
# 1.2mm delays lir/1 LIR_delay_633mm_1-2 1.csv
# - Mean: 10.416 ns \\
# - Standard Deviation: 1.851 ns \\
# - Median: 10.300 ns \\
# 1.2mm delays lir/2 LIR_delay_940mm_1-2 1.csv
# - Mean: 7.447 ns \\
# - Standard Deviation: 4.322 ns \\
# - Median: 6.800 ns \\
# 1.2mm delays lir/3 LIR_delay_1246mm_1-2 2.csv
# - Mean: -4.915 ns \\
# - Standard Deviation: 16.284 ns \\
# - Median: 2.200 ns \\
# 1.2mm delays lir/4 LIR_delay_1552mm_1-2 2.csv
# - Mean: -0.989 ns \\
# - Standard Deviation: 12.913 ns \\
# - Median: -0.700 ns \\
# 1.2mm delays lir/5 LIR_delay_1859mm_1-2 2.csv
# - Mean: -4.218 ns \\
# - Standard Deviation: 11.074 ns \\
# - Median: -3.800 ns \\
# 1.2mm delays lir/6 LIR_delay_2165mm_1-2 2.csv
# - Mean: -7.407 ns \\
# - Standard Deviation: 15.071 ns \\
# - Median: -7.800 ns \\
# 1.2mm delays lir/7 LIR_delay_2417mm_1-2 2.csv
# - Mean: -9.746 ns \\
# - Standard Deviation: 17.641 ns \\
# - Median: -11.100 ns \\

# %%
for f in sorted(glob.glob(os.path.join("1.2mm delays lir", "*.csv"))):
    print(f)
    tds = Timing('t@max', channels=['1', '4'], data = f).single_histograms()
# Out:
# 1.2mm delays lir/0 LIR_delay_327mm_1-2 0.csv
# Channel 1 stats
# - Mean: 14.235 ns \\
# - Standard Deviation: 9.597 ns \\
# - Median: 14.800 ns \\
#
# Channel 4 stats
# - Mean: 0.879 ns \\
# - Standard Deviation: 0.708 ns \\
# - Median: 0.800 ns \\
# 1.2mm delays lir/1 LIR_delay_633mm_1-2 1.csv
# Channel 1 stats
# - Mean: 11.114 ns \\
# - Standard Deviation: 1.888 ns \\
# - Median: 10.900 ns \\
#
# Channel 4 stats
# - Mean: 0.699 ns \\
# - Standard Deviation: 0.634 ns \\
# - Median: 0.600 ns \\
# 1.2mm delays lir/2 LIR_delay_940mm_1-2 1.csv
# Channel 1 stats
# - Mean: 8.093 ns \\
# - Standard Deviation: 4.323 ns \\
# - Median: 7.500 ns \\
#
# Channel 4 stats
# - Mean: 0.647 ns \\
# - Standard Deviation: 0.663 ns \\
# - Median: 0.600 ns \\
# 1.2mm delays lir/3 LIR_delay_1246mm_1-2 2.csv
# Channel 1 stats
# - Mean: -4.197 ns \\
# - Standard Deviation: 16.413 ns \\
# - Median: 3.100 ns \\
#
# Channel 4 stats
# - Mean: 0.717 ns \\
# - Standard Deviation: 0.597 ns \\
# - Median: 0.600 ns \\
# 1.2mm delays lir/4 LIR_delay_1552mm_1-2 2.csv
# Channel 1 stats
# - Mean: -0.350 ns \\
# - Standard Deviation: 12.928 ns \\
# - Median: 0.100 ns \\
#
# Channel 4 stats
# - Mean: 0.639 ns \\
# - Standard Deviation: 0.629 ns \\
# - Median: 0.600 ns \\
# 1.2mm delays lir/5 LIR_delay_1859mm_1-2 2.csv
# Channel 1 stats
# - Mean: -3.560 ns \\
# - Standard Deviation: 11.113 ns \\
# - Median: -3.100 ns \\
#
# Channel 4 stats
# - Mean: 0.658 ns \\
# - Standard Deviation: 0.702 ns \\
# - Median: 0.600 ns \\
# 1.2mm delays lir/6 LIR_delay_2165mm_1-2 2.csv
# Channel 1 stats
# - Mean: -6.786 ns \\
# - Standard Deviation: 15.091 ns \\
# - Median: -7.200 ns \\
#
# Channel 4 stats
# - Mean: 0.621 ns \\
# - Standard Deviation: 0.607 ns \\
# - Median: 0.600 ns \\
# 1.2mm delays lir/7 LIR_delay_2417mm_1-2 2.csv
# Channel 1 stats
# - Mean: -9.210 ns \\
# - Standard Deviation: 17.621 ns \\
# - Median: -10.500 ns \\
#
# Channel 4 stats
# - Mean: 0.537 ns \\
# - Standard Deviation: 0.580 ns \\
# - Median: 0.500 ns \\

# %%
print(tds)
# Out:
# None

# %%
for f in sorted(glob.glob(os.path.join("1.8mm delays lir", "*.csv"))):
    print(f)
    tds = Timing('t@max', channels=['1', '4'], data = f).td_TAM()
# Out:
# 1.8mm delays lir/0 LIR_delay_327mm_1-8.csv
# - Mean: 14.448 ns \\
# - Standard Deviation: 2.027 ns \\
# - Median: 14.500 ns \\
# 1.8mm delays lir/1 LIR_delay_633mm_1-8.csv
# - Mean: 10.757 ns \\
# - Standard Deviation: 2.025 ns \\
# - Median: 10.500 ns \\
# 1.8mm delays lir/2 LIR_delay_940mm_1-8.csv
# - Mean: 7.091 ns \\
# - Standard Deviation: 1.958 ns \\
# - Median: 7.200 ns \\
# 1.8mm delays lir/3 LIR_delay_1246mm_1-8.csv
# - Mean: 2.991 ns \\
# - Standard Deviation: 1.777 ns \\
# - Median: 3.000 ns \\
# 1.8mm delays lir/4 LIR_delay_1552mm_1-8.csv
# - Mean: -0.546 ns \\
# - Standard Deviation: 1.660 ns \\
# - Median: -0.500 ns \\
# 1.8mm delays lir/5 LIR_delay_1859mm_1-8.csv
# - Mean: -3.874 ns \\
# - Standard Deviation: 1.715 ns \\
# - Median: -3.900 ns \\
# 1.8mm delays lir/6 LIR_delay_2165mm_1-8.csv
# - Mean: -7.160 ns \\
# - Standard Deviation: 3.806 ns \\
# - Median: -7.700 ns \\
# 1.8mm delays lir/7 LIR_delay_2417mm_1-8.csv
# - Mean: -10.076 ns \\
# - Standard Deviation: 6.660 ns \\
# - Median: -11.000 ns \\

# %%
for f in sorted(glob.glob(os.path.join("1.8mm delays lir", "*.csv"))):
    print(f)
    tds = Timing('t@max', channels=['1', '4'], data = f).single_histograms()
# Out:
# 1.8mm delays lir/0 LIR_delay_327mm_1-8.csv
# Channel 1 stats
# - Mean: 17.502 ns \\
# - Standard Deviation: 1.941 ns \\
# - Median: 17.700 ns \\
#
# Channel 4 stats
# - Mean: 3.053 ns \\
# - Standard Deviation: 0.829 ns \\
# - Median: 3.100 ns \\
# 1.8mm delays lir/1 LIR_delay_633mm_1-8.csv
# Channel 1 stats
# - Mean: 13.478 ns \\
# - Standard Deviation: 1.989 ns \\
# - Median: 13.100 ns \\
#
# Channel 4 stats
# - Mean: 2.720 ns \\
# - Standard Deviation: 0.821 ns \\
# - Median: 2.800 ns \\
# 1.8mm delays lir/2 LIR_delay_940mm_1-8.csv
# Channel 1 stats
# - Mean: 9.484 ns \\
# - Standard Deviation: 1.962 ns \\
# - Median: 9.500 ns \\
#
# Channel 4 stats
# - Mean: 2.393 ns \\
# - Standard Deviation: 0.890 ns \\
# - Median: 2.300 ns \\
# 1.8mm delays lir/3 LIR_delay_1246mm_1-8.csv
# Channel 1 stats
# - Mean: 5.313 ns \\
# - Standard Deviation: 1.862 ns \\
# - Median: 5.300 ns \\
#
# Channel 4 stats
# - Mean: 2.322 ns \\
# - Standard Deviation: 0.927 ns \\
# - Median: 2.300 ns \\
# 1.8mm delays lir/4 LIR_delay_1552mm_1-8.csv
# Channel 1 stats
# - Mean: 1.669 ns \\
# - Standard Deviation: 1.735 ns \\
# - Median: 1.900 ns \\
#
# Channel 4 stats
# - Mean: 2.215 ns \\
# - Standard Deviation: 0.934 ns \\
# - Median: 2.200 ns \\
# 1.8mm delays lir/5 LIR_delay_1859mm_1-8.csv
# Channel 1 stats
# - Mean: -2.009 ns \\
# - Standard Deviation: 1.687 ns \\
# - Median: -2.000 ns \\
#
# Channel 4 stats
# - Mean: 1.865 ns \\
# - Standard Deviation: 0.879 ns \\
# - Median: 1.900 ns \\
# 1.8mm delays lir/6 LIR_delay_2165mm_1-8.csv
# Channel 1 stats
# - Mean: -5.507 ns \\
# - Standard Deviation: 3.668 ns \\
# - Median: -5.800 ns \\
#
# Channel 4 stats
# - Mean: 1.652 ns \\
# - Standard Deviation: 0.926 ns \\
# - Median: 1.700 ns \\
# 1.8mm delays lir/7 LIR_delay_2417mm_1-8.csv
# Channel 1 stats
# - Mean: -8.631 ns \\
# - Standard Deviation: 6.476 ns \\
# - Median: -9.500 ns \\
#
# Channel 4 stats
# - Mean: 1.445 ns \\
# - Standard Deviation: 0.899 ns \\
# - Median: 1.400 ns \\

# %%
for f in sorted(glob.glob(os.path.join("2.0mm delays lir", "*.csv"))):
    print(f)
    tds = Timing('t@max', channels=['1', '4'], data = f).td_TAM()
# Out:
# 2.0mm delays lir/0 LIR_delay_327mm_2-0.csv
# - Mean: 14.042 ns \\
# - Standard Deviation: 2.387 ns \\
# - Median: 14.100 ns \\
# 2.0mm delays lir/1 LIR_delay_633mm_2-0.csv
# - Mean: 10.366 ns \\
# - Standard Deviation: 2.110 ns \\
# - Median: 10.200 ns \\
# 2.0mm delays lir/2 LIR_delay_940mm_2-0.csv
# - Mean: 6.070 ns \\
# - Standard Deviation: 4.908 ns \\
# - Median: 6.400 ns \\
# 2.0mm delays lir/3 LIR_delay_1246mm_2-0.csv
# - Mean: 6.134 ns \\
# - Standard Deviation: 4.394 ns \\
# - Median: 6.600 ns \\
# 2.0mm delays lir/4 LIR_delay_1552mm_2-0.csv
# - Mean: 2.520 ns \\
# - Standard Deviation: 4.580 ns \\
# - Median: 3.000 ns \\
# 2.0mm delays lir/5 LIR_delay_1859mm_2-0.csv
# - Mean: -5.939 ns \\
# - Standard Deviation: 8.255 ns \\
# - Median: -4.100 ns \\
# 2.0mm delays lir/6 LIR_delay_2165mm_2-0.csv
# - Mean: -8.544 ns \\
# - Standard Deviation: 6.043 ns \\
# - Median: -7.700 ns \\
# 2.0mm delays lir/7 LIR_delay_2417mm_2-0.csv
# - Mean: -13.513 ns \\
# - Standard Deviation: 14.066 ns \\
# - Median: -11.400 ns \\

# %%
for f in sorted(glob.glob(os.path.join("2.0mm delays lir", "*.csv"))):
    print(f)
    tds = Timing('t@max', channels=['1', '4'], data = f).single_histograms()
# Out:
# 2.0mm delays lir/0 LIR_delay_327mm_2-0.csv
# Channel 1 stats
# - Mean: 15.651 ns \\
# - Standard Deviation: 2.449 ns \\
# - Median: 15.800 ns \\
#
# Channel 4 stats
# - Mean: 1.609 ns \\
# - Standard Deviation: 0.821 ns \\
# - Median: 1.600 ns \\
# 2.0mm delays lir/1 LIR_delay_633mm_2-0.csv
# Channel 1 stats
# - Mean: 12.030 ns \\
# - Standard Deviation: 2.116 ns \\
# - Median: 12.000 ns \\
#
# Channel 4 stats
# - Mean: 1.664 ns \\
# - Standard Deviation: 0.838 ns \\
# - Median: 1.700 ns \\
# 2.0mm delays lir/2 LIR_delay_940mm_2-0.csv
# Channel 1 stats
# - Mean: 7.602 ns \\
# - Standard Deviation: 5.095 ns \\
# - Median: 8.100 ns \\
#
# Channel 4 stats
# - Mean: 1.532 ns \\
# - Standard Deviation: 0.884 ns \\
# - Median: 1.600 ns \\
# 2.0mm delays lir/3 LIR_delay_1246mm_2-0.csv
# Channel 1 stats
# - Mean: 7.701 ns \\
# - Standard Deviation: 4.550 ns \\
# - Median: 8.300 ns \\
#
# Channel 4 stats
# - Mean: 1.567 ns \\
# - Standard Deviation: 0.883 ns \\
# - Median: 1.600 ns \\
# 2.0mm delays lir/4 LIR_delay_1552mm_2-0.csv
# Channel 1 stats
# - Mean: 3.947 ns \\
# - Standard Deviation: 4.745 ns \\
# - Median: 4.700 ns \\
#
# Channel 4 stats
# - Mean: 1.427 ns \\
# - Standard Deviation: 0.830 ns \\
# - Median: 1.400 ns \\
# 2.0mm delays lir/5 LIR_delay_1859mm_2-0.csv
# Channel 1 stats
# - Mean: -4.867 ns \\
# - Standard Deviation: 8.421 ns \\
# - Median: -2.800 ns \\
#
# Channel 4 stats
# - Mean: 1.072 ns \\
# - Standard Deviation: 0.685 ns \\
# - Median: 1.100 ns \\
# 2.0mm delays lir/6 LIR_delay_2165mm_2-0.csv
# Channel 1 stats
# - Mean: -7.387 ns \\
# - Standard Deviation: 6.205 ns \\
# - Median: -6.300 ns \\
#
# Channel 4 stats
# - Mean: 1.157 ns \\
# - Standard Deviation: 0.760 ns \\
# - Median: 1.100 ns \\
# 2.0mm delays lir/7 LIR_delay_2417mm_2-0.csv
# Channel 1 stats
# - Mean: -12.780 ns \\
# - Standard Deviation: 14.127 ns \\
# - Median: -10.600 ns \\
#
# Channel 4 stats
# - Mean: 0.733 ns \\
# - Standard Deviation: 0.589 ns \\
# - Median: 0.600 ns \\
